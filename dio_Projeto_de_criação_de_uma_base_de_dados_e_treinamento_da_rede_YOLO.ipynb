# %% [markdown]
# <a href="https://colab.research.google.com/github/el-danieel/dio-Projeto-de-criacao-de-uma-base-de-dados-e-treinamento-da-rede-YOLO/blob/main/dio_Projeto_de_cria%C3%A7%C3%A3o_de_uma_base_de_dados_e_treinamento_da_rede_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import matplotlib.pyplot as plt
import cv2

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
img_path = 'dog_bike.jpg'
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Inference
results = model(img)

# Results
results.print()
results.show()  # or .show()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-2-20 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 445x658 1 bicycle, 1 bench, 1 dog
# Speed: 18.9ms pre-process, 404.6ms inference, 4.5ms NMS per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=658x445>
